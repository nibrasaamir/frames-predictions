# %% [markdown]
# RNN

# %%
import matplotlib.pyplot as plt


epochs = list(range(1, 41))
loss = [
    0.5852, 0.2308, 0.2117, 0.1938, 0.1952, 0.1841, 0.1868, 0.1635, 0.1710, 0.1665,
    0.1702, 0.1605, 0.1756, 0.1803, 0.1734, 0.1820, 0.1731, 0.1626, 0.1671, 0.1845,
    0.1599, 0.1627, 0.1718, 0.1645, 0.1691, 0.1723, 0.1536, 0.1604, 0.1599, 0.1649,
    0.1637, 0.1468, 0.1571, 0.1655, 0.1622, 0.1527, 0.1603, 0.1551, 0.1587, 0.1493
]
mae = [
    0.1414, 0.0571, 0.0476, 0.0433, 0.0435, 0.0401, 0.0416, 0.0346, 0.0369, 0.0351,
    0.0364, 0.0340, 0.0379, 0.0365, 0.0337, 0.0365, 0.0354, 0.0321, 0.0344, 0.0382,
    0.0312, 0.0336, 0.0366, 0.0320, 0.0360, 0.0330, 0.0300, 0.0317, 0.0305, 0.0326,
    0.0305, 0.0296, 0.0306, 0.0327, 0.0323, 0.0317, 0.0327, 0.0319, 0.0309, 0.0311
]

# Plotting Loss over Epochs
plt.figure(figsize=(12, 6))
plt.plot(epochs, loss, label='Loss', marker='o', color='blue')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# Plotting MAE over Epochs
plt.figure(figsize=(12, 6))
plt.plot(epochs, mae, label='Mean Absolute Error (MAE)', marker='o', color='green')
plt.title('Mean Absolute Error Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.grid(True)
plt.legend()
plt.show()

# Combined Plot for Loss and MAE
plt.figure(figsize=(12, 6))
plt.plot(epochs, loss, label='Loss', marker='o', color='blue')
plt.plot(epochs, mae, label='MAE', marker='x', color='green')
plt.title('Training Loss and MAE Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Values')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# TRANSFORMER

# %%
import matplotlib.pyplot as plt

# Provided data for the plots
epochs = list(range(1, 85))  
loss = [
    1.1238, 1.0674, 1.0634, 1.0362, 1.0305, 0.9998, 0.9941, 0.9706, 0.9630, 0.9492, 0.9474, 0.9248,
    0.9146, 0.9109, 0.8893, 0.8774, 0.8777, 0.8561, 0.8513, 0.8394, 0.8279, 0.8255, 0.8102, 0.7993,
    0.7974, 0.7847, 0.7740, 0.7654, 0.7607, 0.7489, 0.7368, 0.7351, 0.7226, 0.7175, 0.7073, 0.6968,
    0.6874, 0.6873, 0.6743, 0.6694, 0.6574, 0.6451, 0.6416, 0.6279, 0.6184, 0.6112, 0.5988, 0.5966,
    0.5803, 0.5732, 0.5657, 0.5543, 0.5481, 0.5386, 0.5314, 0.5254, 0.5153, 0.5041, 0.4982, 0.4901,
    0.4810, 0.4716, 0.4647, 0.4548, 0.4471, 0.4410, 0.4322, 0.4228, 0.4167, 0.4068, 0.4012, 0.3930,
    0.3842, 0.3765, 0.3688, 0.3610, 0.3512, 0.3453, 0.3387, 0.3302, 0.3246, 0.3162, 0.3103, 0.3024
]
mae = [
    0.2467, 0.2347, 0.2252, 0.2173, 0.2094, 0.2001, 0.1932, 0.1878, 0.1812, 0.1767, 0.1721, 0.1664,
    0.1620, 0.1576, 0.1521, 0.1477, 0.1438, 0.1402, 0.1361, 0.1325, 0.1291, 0.1264, 0.1223, 0.1185,
    0.1156, 0.1127, 0.1100, 0.1071, 0.1048, 0.1023, 0.0998, 0.0974, 0.0953, 0.0933, 0.0912, 0.0892,
    0.0874, 0.0855, 0.0838, 0.0821, 0.0804, 0.0787, 0.0772, 0.0758, 0.0741, 0.0725, 0.0711, 0.0697,
    0.0684, 0.0670, 0.0658, 0.0646, 0.0633, 0.0621, 0.0610, 0.0599, 0.0587, 0.0576, 0.0565, 0.0555,
    0.0544, 0.0534, 0.0524, 0.0514, 0.0505, 0.0496, 0.0487, 0.0478, 0.0469, 0.0461, 0.0453, 0.0444,
    0.0436, 0.0428, 0.0420, 0.0412, 0.0404, 0.0397, 0.0389, 0.0382, 0.0375, 0.0368, 0.0361, 0.0354
]

# Plotting Loss over Epochs
plt.figure(figsize=(12, 6))
plt.plot(epochs, loss, label='Loss', marker='o', color='blue')
plt.title('Training Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# Plotting MAE over Epochs
plt.figure(figsize=(12, 6))
plt.plot(epochs, mae, label='Mean Absolute Error (MAE)', marker='o', color='green')
plt.title('Mean Absolute Error Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.grid(True)
plt.legend()
plt.show()

# Combined Plot for Loss and MAE
plt.figure(figsize=(12, 6))
plt.plot(epochs, loss, label='Loss', marker='o', color='blue')
plt.plot(epochs, mae, label='MAE', marker='x', color='green')
plt.title('Training Loss and MAE Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Values')
plt.grid(True)
plt.legend()
plt.show()

# %%
print(len(epochs), len(loss), len(mae))
# Out:
# 86 84 84

# %% [markdown]
# LSTM

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Loss, MAE, and SSIM metrics across epochs
epochs = np.arange(1, 31)
loss = [
    0.5036, 0.2503, 0.2228, 0.2249, 0.2353, 0.2024, 0.1881, 0.1822, 0.1570, 0.1556,
    0.1513, 0.1542, 0.1510, 0.1377, 0.1403, 0.1554, 0.1317, 0.1314, 0.1392, 0.1494,
    0.1330, 0.1307, 0.1299, 0.1356, 0.1180, 0.1221, 0.1238, 0.1291, 0.1198, 0.1216
]
mae = [
    0.1346, 0.0742, 0.0657, 0.0652, 0.0659, 0.0600, 0.0534, 0.0528, 0.0432, 0.0438,
    0.0423, 0.0437, 0.0429, 0.0377, 0.0379, 0.0408, 0.0371, 0.0343, 0.0404, 0.0393,
    0.0358, 0.0346, 0.0354, 0.0345, 0.0323, 0.0323, 0.0326, 0.0334, 0.0325, 0.0324
]
ssim = [
    0.6320, 0.8248, 0.8430, 0.8413, 0.8307, 0.8582, 0.8655, 0.8707, 0.8864, 0.8882,
    0.8916, 0.8896, 0.8921, 0.9004, 0.8983, 0.8859, 0.9059, 0.9031, 0.9015, 0.8900,
    0.9031, 0.9042, 0.9060, 0.9000, 0.9144, 0.9103, 0.9089, 0.9053, 0.9130, 0.9108
]

# Plot Loss
plt.figure(figsize=(15, 5))
plt.plot(epochs, loss, label='Loss', marker='o', color='blue')
plt.title('Loss Over Epochs for LSTM Model')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# Plot MAE
plt.figure(figsize=(15, 5))
plt.plot(epochs, mae, label='Mean Absolute Error (MAE)', marker='o', color='orange')
plt.title('Mean Absolute Error (MAE) Over Epochs for LSTM Model')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# Plot SSIM
plt.figure(figsize=(15, 5))
plt.plot(epochs, ssim, label='SSIM Metric', marker='o', color='green')
plt.title('SSIM Metric Over Epochs for LSTM Model')
plt.xlabel('Epochs')
plt.ylabel('SSIM Metric')
plt.grid(alpha=0.5)
plt.legend()
plt.show()

# Combined Plot
plt.figure(figsize=(15, 5))
plt.plot(epochs, loss, label='Loss', marker='o', color='blue')
plt.plot(epochs, mae, label='MAE', marker='o', color='orange')
plt.plot(epochs, ssim, label='SSIM', marker='o', color='green')
plt.title('Loss, MAE, and SSIM Over Epochs for LSTM Model')
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.grid(alpha=0.5)
plt.legend()
plt.show()
